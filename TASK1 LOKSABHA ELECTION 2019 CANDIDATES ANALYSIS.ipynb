# %% [markdown]
# # TASK1

# %% [markdown]
# # INTERNSHIP PROJECT OF DATA SCIENCE FROM CODTECH IT SOLUTIONS

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS(EDA) OF                                                     INDIA'S LOKSABHA ELECTION  2019 CANDIDATES

# %%
import pandas as pd

# %%
dataset=pd.read_csv("LS_2.0.csv")

# %%
dataset
# Out:
#               STATE     CONSTITUENCY                   NAME  WINNER PARTY  \
# 0         Telangana         ADILABAD         SOYAM BAPU RAO       1   BJP
# 1         Telangana         ADILABAD           Godam Nagesh       0   TRS
# 2         Telangana         ADILABAD          RATHOD RAMESH       0   INC
# 3         Telangana         ADILABAD                   NOTA       0  NOTA
# 4     Uttar Pradesh             AGRA  Satyapal Singh Baghel       1   BJP
# ...             ...              ...                    ...     ...   ...
# 2258    Maharashtra  YAVATMAL-WASHIM     Anil Jayram Rathod       0   IND
# 2259      Telangana        ZAHIRABAD              B.B.PATIL       1   TRS
# 2260      Telangana        ZAHIRABAD        MADAN MOHAN RAO       0   INC
# 2261      Telangana        ZAHIRABAD     BANALA LAXMA REDDY       0   BJP
# 2262      Telangana        ZAHIRABAD                   NOTA       0  NOTA
#
#      SYMBOL GENDER CRIMINAL\nCASES   AGE CATEGORY      EDUCATION  \
# ...

# %% [markdown]
# # data preprocessing

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2263 entries, 0 to 2262
# Data columns (total 19 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   STATE                                     2263 non-null   object
#  1   CONSTITUENCY                              2263 non-null   object
#  2   NAME                                      2263 non-null   object
#  3   WINNER                                    2263 non-null   int64
#  4   PARTY                                     2263 non-null   object
#  5   SYMBOL                                    2018 non-null   object
#  6   GENDER                                    2018 non-null   object
#  7   CRIMINAL
# CASES                            2018 non-null   object
#  8   AGE                                       2018 non-null   float64
#  9   CATEGORY                                  2018 non-null   object
# ...

# %%
#rename to the respected column name
dataset.rename(columns={'CRIMINAL\nCASES':'CRIMINALCASES','GENERAL\nVOTES':'GENERAL VOTES','POSTAL\nVOTES':'POSTAL VOTES','TOTAL\nVOTES':'TOTAL VOTES'},inplace=True)

# %%
dataset
# Out:
#               STATE     CONSTITUENCY                   NAME  WINNER PARTY  \
# 0         Telangana         ADILABAD         SOYAM BAPU RAO       1   BJP
# 1         Telangana         ADILABAD           Godam Nagesh       0   TRS
# 2         Telangana         ADILABAD          RATHOD RAMESH       0   INC
# 3         Telangana         ADILABAD                   NOTA       0  NOTA
# 4     Uttar Pradesh             AGRA  Satyapal Singh Baghel       1   BJP
# ...             ...              ...                    ...     ...   ...
# 2258    Maharashtra  YAVATMAL-WASHIM     Anil Jayram Rathod       0   IND
# 2259      Telangana        ZAHIRABAD              B.B.PATIL       1   TRS
# 2260      Telangana        ZAHIRABAD        MADAN MOHAN RAO       0   INC
# 2261      Telangana        ZAHIRABAD     BANALA LAXMA REDDY       0   BJP
# 2262      Telangana        ZAHIRABAD                   NOTA       0  NOTA
#
#      SYMBOL GENDER CRIMINALCASES   AGE CATEGORY      EDUCATION  \
# ...

# %% [markdown]
# # working education column to convert defined unique words

# %%
dataset.EDUCATION.unique()
# Out:
# array(['12th Pass', 'Post Graduate', nan, 'Doctorate', 'Graduate',
#        'Others', '10th Pass', '8th Pass', 'Graduate Professional',
#        'Literate', 'Illiterate', '5th Pass', 'Not Available',
#        'Post Graduate\n'], dtype=object)

# %%
dataset['EDUCATION'].replace(to_replace=['Illiterate','Not Available','Others'],value='Illiterate',inplace=True)
dataset['EDUCATION'].replace(to_replace=['12th Pass','10th Pass','8th Pass','5th Pass','Literate'],value='scholl level',inplace=True)
dataset['EDUCATION'].replace(to_replace=['Graduate Professional','Graduate'],value='Graduate',inplace=True)
dataset['EDUCATION'].replace(to_replace=['Post Graduate','Post Graduate\n','Doctorate'],value='Post Graduate/Doctorate',inplace=True)

# %%
dataset.EDUCATION.unique()
# Out:
# array(['scholl level', 'Post Graduate/Doctorate', nan, 'Graduate',
#        'Illiterate'], dtype=object)

# %%
dataset
# Out:
#               STATE     CONSTITUENCY                   NAME  WINNER PARTY  \
# 0         Telangana         ADILABAD         SOYAM BAPU RAO       1   BJP
# 1         Telangana         ADILABAD           Godam Nagesh       0   TRS
# 2         Telangana         ADILABAD          RATHOD RAMESH       0   INC
# 3         Telangana         ADILABAD                   NOTA       0  NOTA
# 4     Uttar Pradesh             AGRA  Satyapal Singh Baghel       1   BJP
# ...             ...              ...                    ...     ...   ...
# 2258    Maharashtra  YAVATMAL-WASHIM     Anil Jayram Rathod       0   IND
# 2259      Telangana        ZAHIRABAD              B.B.PATIL       1   TRS
# 2260      Telangana        ZAHIRABAD        MADAN MOHAN RAO       0   INC
# 2261      Telangana        ZAHIRABAD     BANALA LAXMA REDDY       0   BJP
# 2262      Telangana        ZAHIRABAD                   NOTA       0  NOTA
#
#      SYMBOL GENDER CRIMINALCASES   AGE CATEGORY                EDUCATION  \
# ...

# %% [markdown]
# # working with criminal cese column

# %%
dataset['CRIMINALCASES']=dataset['CRIMINALCASES'].replace({'Not available':0,'Not Available':0})
dataset['CRIMINALCASES']=dataset['CRIMINALCASES'].fillna(0)

# %%
dataset['CRIMINALCASES']=dataset['CRIMINALCASES'].astype('int64')

# %%
dataset['CRIMINALCASES'].unique()
# Out:
# array([ 52,   0,   3,   5,   1,   6,   2,   4,   9,   7,  40,   8,  24,
#         14,  28,  12,  11,  13,  15, 204,  10,  22,  31,  42,  16, 240,
#         41,  18], dtype=int64)

# %%
dataset
# Out:
#               STATE     CONSTITUENCY                   NAME  WINNER PARTY  \
# 0         Telangana         ADILABAD         SOYAM BAPU RAO       1   BJP
# 1         Telangana         ADILABAD           Godam Nagesh       0   TRS
# 2         Telangana         ADILABAD          RATHOD RAMESH       0   INC
# 3         Telangana         ADILABAD                   NOTA       0  NOTA
# 4     Uttar Pradesh             AGRA  Satyapal Singh Baghel       1   BJP
# ...             ...              ...                    ...     ...   ...
# 2258    Maharashtra  YAVATMAL-WASHIM     Anil Jayram Rathod       0   IND
# 2259      Telangana        ZAHIRABAD              B.B.PATIL       1   TRS
# 2260      Telangana        ZAHIRABAD        MADAN MOHAN RAO       0   INC
# 2261      Telangana        ZAHIRABAD     BANALA LAXMA REDDY       0   BJP
# 2262      Telangana        ZAHIRABAD                   NOTA       0  NOTA
#
#      SYMBOL GENDER  CRIMINALCASES   AGE CATEGORY                EDUCATION  \
# ...

# %% [markdown]
# # Data cleaning

# %%
def data_cleaner(x):
    try:
        x = x.split('\n')[0]
        x = x.replace('Rs', '')
        x = x.replace(',', '')
        x = x.strip()
        return int(x)
    except:
        x = 0
        return int(x)
dataset['ASSETS'] = dataset['ASSETS'].apply((data_cleaner))
dataset['LIABILITIES'] = dataset['LIABILITIES'].apply((data_cleaner))
dataset.head()
# Out:
#            STATE CONSTITUENCY                   NAME  WINNER PARTY SYMBOL  \
# 0      Telangana     ADILABAD         SOYAM BAPU RAO       1   BJP  Lotus
# 1      Telangana     ADILABAD           Godam Nagesh       0   TRS    Car
# 2      Telangana     ADILABAD          RATHOD RAMESH       0   INC   Hand
# 3      Telangana     ADILABAD                   NOTA       0  NOTA    NaN
# 4  Uttar Pradesh         AGRA  Satyapal Singh Baghel       1   BJP  Lotus
#
#   GENDER  CRIMINALCASES   AGE CATEGORY                EDUCATION  ASSETS  \
# 0   MALE             52  52.0       ST             scholl level       0
# 1   MALE              0  54.0       ST  Post Graduate/Doctorate       0
# 2   MALE              3  52.0       ST             scholl level       0
# 3    NaN              0   NaN      NaN                      NaN       0
# 4   MALE              5  58.0       SC  Post Graduate/Doctorate       0
#
#    LIABILITIES  GENERAL VOTES  POSTAL VOTES  TOTAL VOTES  \
# ...

# %%
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# STATE                                        0
# CONSTITUENCY                                 0
# NAME                                         0
# WINNER                                       0
# PARTY                                        0
# SYMBOL                                       0
# GENDER                                       0
# CRIMINALCASES                                0
# AGE                                          0
# CATEGORY                                     0
# EDUCATION                                    0
# ASSETS                                       0
# LIABILITIES                                  0
# GENERAL VOTES                                0
# POSTAL VOTES                                 0
# TOTAL VOTES                                  0
# OVER TOTAL ELECTORS \nIN CONSTITUENCY        0
# OVER TOTAL VOTES POLLED \nIN CONSTITUENCY    0
# TOTAL ELECTORS                               0
# dtype: int64

# %% [markdown]
# # dataset to divide quan,qual for outlayer findout purposes

# %%
def quanqual(dataset):
    quan=[]
    qual=[]
    for columnName in dataset.columns:
        if (dataset[columnName].dtype=='O'):
            qual.append(columnName)
        else:
            quan.append(columnName)
    return quan,qual

# %%
quan,qual=quanqual(dataset)

# %%
dataset[quan]
# Out:
#       WINNER  CRIMINALCASES   AGE  ASSETS  LIABILITIES  GENERAL VOTES  \
# 0          1             52  52.0       0            0         376892
# 1          0              0  54.0       0            0         318665
# 2          0              3  52.0       0            0         314057
# 4          1              5  58.0       0            0         644459
# 5          0              0  47.0       0            0         434199
# ...      ...            ...   ...     ...          ...            ...
# 2257       0              0  28.0       0            0          20563
# 2258       0              0  43.0       0            0          14661
# 2259       1             18  63.0       0            0         434066
# 2260       0              0  49.0       0            0         427900
# 2261       0              3  47.0       0            0         138731
#
#       POSTAL VOTES  TOTAL VOTES  OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# ...

# %%
dataset[qual]
# Out:
#               STATE     CONSTITUENCY                    NAME  PARTY    SYMBOL  \
# 0         Telangana         ADILABAD          SOYAM BAPU RAO    BJP     Lotus
# 1         Telangana         ADILABAD            Godam Nagesh    TRS       Car
# 2         Telangana         ADILABAD           RATHOD RAMESH    INC      Hand
# 4     Uttar Pradesh             AGRA   Satyapal Singh Baghel    BJP     Lotus
# 5     Uttar Pradesh             AGRA        Manoj Kumar Soni    BSP  Elephant
# ...             ...              ...                     ...    ...       ...
# 2257    Maharashtra  YAVATMAL-WASHIM  Vaishali Sudhakar Yede  PHJSP   Whistle
# 2258    Maharashtra  YAVATMAL-WASHIM      Anil Jayram Rathod    IND      SHIP
# 2259      Telangana        ZAHIRABAD               B.B.PATIL    TRS       Car
# 2260      Telangana        ZAHIRABAD         MADAN MOHAN RAO    INC      Hand
# 2261      Telangana        ZAHIRABAD      BANALA LAXMA REDDY    BJP     Lotus
#
# ...

# %%
dataset.describe()
# Out:
#             WINNER  CRIMINALCASES          AGE  ASSETS  LIABILITIES  \
# count  2018.000000    2018.000000  2018.000000  2018.0       2018.0
# mean      0.267096       1.453915    52.273538     0.0          0.0
# std       0.442553       7.636973    11.869373     0.0          0.0
# min       0.000000       0.000000    25.000000     0.0          0.0
# 25%       0.000000       0.000000    43.250000     0.0          0.0
# 50%       0.000000       0.000000    52.000000     0.0          0.0
# 75%       1.000000       1.000000    61.000000     0.0          0.0
# max       1.000000     240.000000    86.000000     0.0          0.0
#
#        GENERAL VOTES  POSTAL VOTES   TOTAL VOTES  \
# count   2.018000e+03   2018.000000  2.018000e+03
# mean    2.911903e+05   1105.111001  2.922954e+05
# std     2.545964e+05   1661.283371  2.555874e+05
# min     1.339000e+03      0.000000  1.342000e+03
# 25%     3.047625e+04     97.000000  3.074375e+04
# 50%     2.846300e+05    463.000000  2.855250e+05
# ...

# %%
import numpy as np

# %%
descriptive=pd.DataFrame(index=["mean","median","mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR","1.5rule","lesser","greater","min","max"],columns=quan)
for columnName in quan:
    descriptive[columnName]["mean"]=dataset[columnName].mean()
    descriptive[columnName]["median"]=dataset[columnName].median()
    descriptive[columnName]["mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
    descriptive[columnName]["greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
    descriptive[columnName]["min"]=dataset[columnName].min()
    descriptive[columnName]["max"]=dataset[columnName].max()

# %%
descriptive
# Out:
#            WINNER CRIMINALCASES        AGE ASSETS LIABILITIES  GENERAL VOTES  \
# mean     0.267096      1.453915  52.273538    0.0         0.0  291190.250248
# median        0.0           0.0       52.0    0.0         0.0       284630.0
# mode            0             0       55.0      0           0          11054
# Q1:25%        0.0           0.0      43.25    0.0         0.0       30476.25
# Q2:50%        0.0           0.0       52.0    0.0         0.0       284630.0
# Q3:75%        1.0           1.0       61.0    0.0         0.0       505862.0
# 99%           1.0         12.83       78.0    0.0         0.0      860364.94
# Q4:100%       1.0         240.0       86.0    0.0         0.0      1066824.0
# IQR           1.0           1.0      17.75    0.0         0.0      475385.75
# 1.5rule       1.5           1.5     26.625    0.0         0.0     713078.625
# lesser       -1.5          -1.5     16.625    0.0         0.0    -682602.375
# ...

# %% [markdown]
# # to check lesser outlayer and greater outlayer& to convert it

# %%
lesser=[]
greater=[]

for columnName in quan:
    if(descriptive[columnName]["min"]<descriptive[columnName]["lesser"]):
        lesser.append(columnName)
    if(descriptive[columnName]["max"]>descriptive[columnName]["greater"]):    
        greater.append(columnName)

# %%
lesser
# Out:
# ['TOTAL ELECTORS']

# %%
greater
# Out:
# ['CRIMINALCASES', 'POSTAL VOTES', 'TOTAL ELECTORS']

# %%
for column in lesser:
    dataset[column][dataset[column]<descriptive[column]["lesser"]]=descriptive[column]["lesser"]
for column in greater:
     dataset[column][dataset[column]>descriptive[column]["greater"]]=descriptive[column]["greater"]
# Out:
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\udhaya\Anaconda3\envs\aim1\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
descriptive=pd.DataFrame(index=["mean","median","mode","Q1:25%","Q2:50%","Q3:75%","99%","Q4:100%","IQR","1.5rule","lesser","greater","min","max"],columns=quan)
for columnName in quan:
    descriptive[columnName]["mean"]=dataset[columnName].mean()
    descriptive[columnName]["median"]=dataset[columnName].median()
    descriptive[columnName]["mode"]=dataset[columnName].mode()[0]
    descriptive[columnName]["Q1:25%"]=dataset.describe()[columnName]["25%"]
    descriptive[columnName]["Q2:50%"]=dataset.describe()[columnName]["50%"]
    descriptive[columnName]["Q3:75%"]=dataset.describe()[columnName]["75%"]
    descriptive[columnName]["99%"]=np.percentile(dataset[columnName],99)
    descriptive[columnName]["Q4:100%"]=dataset.describe()[columnName]["max"]
    descriptive[columnName]["IQR"]=descriptive[columnName]["Q3:75%"]-descriptive[columnName]["Q1:25%"]
    descriptive[columnName]["1.5rule"]=1.5*descriptive[columnName]["IQR"]
    descriptive[columnName]["lesser"]=descriptive[columnName]["Q1:25%"]-descriptive[columnName]["1.5rule"]
    descriptive[columnName]["greater"]=descriptive[columnName]["Q3:75%"]+descriptive[columnName]["1.5rule"]
    descriptive[columnName]["min"]=dataset[columnName].min()
    descriptive[columnName]["max"]=dataset[columnName].max()

# %%
descriptive
# Out:
#            WINNER CRIMINALCASES        AGE ASSETS LIABILITIES  GENERAL VOTES  \
# mean     0.267096      0.671952  52.273538    0.0         0.0  291190.250248
# median        0.0           0.0       52.0    0.0         0.0       284630.0
# mode            0           0.0       55.0      0           0          11054
# Q1:25%        0.0           0.0      43.25    0.0         0.0       30476.25
# Q2:50%        0.0           0.0       52.0    0.0         0.0       284630.0
# Q3:75%        1.0           1.0       61.0    0.0         0.0       505862.0
# 99%           1.0           2.5       78.0    0.0         0.0      860364.94
# Q4:100%       1.0           2.5       86.0    0.0         0.0      1066824.0
# IQR           1.0           1.0      17.75    0.0         0.0      475385.75
# 1.5rule       1.5           1.5     26.625    0.0         0.0     713078.625
# lesser       -1.5          -1.5     16.625    0.0         0.0    -682602.375
# ...

# %%
lesser=[]
greater=[]

for columnName in quan:
    if(descriptive[columnName]["min"]<descriptive[columnName]["lesser"]):
        lesser.append(columnName)
    if(descriptive[columnName]["max"]>descriptive[columnName]["greater"]):    
        greater.append(columnName)

# %%
lesser
# Out:
# []

# %%
greater
# Out:
# []

# %%
dataset[quan].isnull().sum()
# Out:
# WINNER                                       0
# CRIMINALCASES                                0
# AGE                                          0
# ASSETS                                       0
# LIABILITIES                                  0
# GENERAL VOTES                                0
# POSTAL VOTES                                 0
# TOTAL VOTES                                  0
# OVER TOTAL ELECTORS \nIN CONSTITUENCY        0
# OVER TOTAL VOTES POLLED \nIN CONSTITUENCY    0
# TOTAL ELECTORS                               0
# dtype: int64

# %%
dataset[qual].isnull().sum()
# Out:
# STATE           0
# CONSTITUENCY    0
# NAME            0
# PARTY           0
# SYMBOL          0
# GENDER          0
# CATEGORY        0
# EDUCATION       0
# dtype: int64

# %%
dataset.isnull().sum()
# Out:
# STATE                                        0
# CONSTITUENCY                                 0
# NAME                                         0
# WINNER                                       0
# PARTY                                        0
# SYMBOL                                       0
# GENDER                                       0
# CRIMINALCASES                                0
# AGE                                          0
# CATEGORY                                     0
# EDUCATION                                    0
# ASSETS                                       0
# LIABILITIES                                  0
# GENERAL VOTES                                0
# POSTAL VOTES                                 0
# TOTAL VOTES                                  0
# OVER TOTAL ELECTORS \nIN CONSTITUENCY        0
# OVER TOTAL VOTES POLLED \nIN CONSTITUENCY    0
# TOTAL ELECTORS                               0
# dtype: int64

# %%
df=dataset[quan]

# %%
df
# Out:
#       WINNER  CRIMINALCASES   AGE  ASSETS  LIABILITIES  GENERAL VOTES  \
# 0          1            2.5  52.0       0            0         376892
# 1          0            0.0  54.0       0            0         318665
# 2          0            2.5  52.0       0            0         314057
# 4          1            2.5  58.0       0            0         644459
# 5          0            0.0  47.0       0            0         434199
# ...      ...            ...   ...     ...          ...            ...
# 2257       0            0.0  28.0       0            0          20563
# 2258       0            0.0  43.0       0            0          14661
# 2259       1            2.5  63.0       0            0         434066
# 2260       0            0.0  49.0       0            0         427900
# 2261       0            2.5  47.0       0            0         138731
#
#       POSTAL VOTES  TOTAL VOTES  OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# ...

# %%
cate=dataset[qual]

# %%
cate
# Out:
#               STATE     CONSTITUENCY                    NAME  PARTY    SYMBOL  \
# 0         Telangana         ADILABAD          SOYAM BAPU RAO    BJP     Lotus
# 1         Telangana         ADILABAD            Godam Nagesh    TRS       Car
# 2         Telangana         ADILABAD           RATHOD RAMESH    INC      Hand
# 4     Uttar Pradesh             AGRA   Satyapal Singh Baghel    BJP     Lotus
# 5     Uttar Pradesh             AGRA        Manoj Kumar Soni    BSP  Elephant
# ...             ...              ...                     ...    ...       ...
# 2257    Maharashtra  YAVATMAL-WASHIM  Vaishali Sudhakar Yede  PHJSP   Whistle
# 2258    Maharashtra  YAVATMAL-WASHIM      Anil Jayram Rathod    IND      SHIP
# 2259      Telangana        ZAHIRABAD               B.B.PATIL    TRS       Car
# 2260      Telangana        ZAHIRABAD         MADAN MOHAN RAO    INC      Hand
# 2261      Telangana        ZAHIRABAD      BANALA LAXMA REDDY    BJP     Lotus
#
# ...

# %%
two=[df,cate]

# %%
preprocessedloksabha=pd.concat(two,axis=1)

# %%
preprocessedloksabha
# Out:
#       WINNER  CRIMINALCASES   AGE  ASSETS  LIABILITIES  GENERAL VOTES  \
# 0          1            2.5  52.0       0            0         376892
# 1          0            0.0  54.0       0            0         318665
# 2          0            2.5  52.0       0            0         314057
# 4          1            2.5  58.0       0            0         644459
# 5          0            0.0  47.0       0            0         434199
# ...      ...            ...   ...     ...          ...            ...
# 2257       0            0.0  28.0       0            0          20563
# 2258       0            0.0  43.0       0            0          14661
# 2259       1            2.5  63.0       0            0         434066
# 2260       0            0.0  49.0       0            0         427900
# 2261       0            2.5  47.0       0            0         138731
#
#       POSTAL VOTES  TOTAL VOTES  OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# ...

# %%
preprocessedloksabha.isnull().sum()
# Out:
# WINNER                                       0
# CRIMINALCASES                                0
# AGE                                          0
# ASSETS                                       0
# LIABILITIES                                  0
# GENERAL VOTES                                0
# POSTAL VOTES                                 0
# TOTAL VOTES                                  0
# OVER TOTAL ELECTORS \nIN CONSTITUENCY        0
# OVER TOTAL VOTES POLLED \nIN CONSTITUENCY    0
# TOTAL ELECTORS                               0
# STATE                                        0
# CONSTITUENCY                                 0
# NAME                                         0
# PARTY                                        0
# SYMBOL                                       0
# GENDER                                       0
# CATEGORY                                     0
# EDUCATION                                    0
# dtype: int64

# %%
preprocessedloksabha.to_csv("preprocessedloksabha.csv",index=False)

# %%
import pandas as pd
data=pd.read_csv("preprocessedloksabha.csv")

# %%
data.head(5)
# Out:
#    WINNER  CRIMINALCASES   AGE  ASSETS  LIABILITIES  GENERAL VOTES  \
# 0       1            2.5  52.0       0            0         376892
# 1       0            0.0  54.0       0            0         318665
# 2       0            2.5  52.0       0            0         314057
# 3       1            2.5  58.0       0            0         644459
# 4       0            0.0  47.0       0            0         434199
#
#    POSTAL VOTES  TOTAL VOTES  OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# 0         482.0       377374                              25.330684
# 1         149.0       318814                              21.399929
# 2         181.0       314238                              21.092771
# 3        2416.0       646875                              33.383823
# 4        1130.0       435329                              22.466390
#
#    OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS          STATE  \
# ...

# %% [markdown]
# # univarite & bivarite analysis of loksabha election 2019

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.io as pio
pio.renderers.default="svg"

# %% [markdown]
# # Q1)which are the top 3 states with most parlimentary constituencies

# %%
Num_cons = data.groupby('STATE')['CONSTITUENCY'].nunique().sort_values(ascending=False).reset_index()

# %%
Num_cons.head(5)
# Out:
#            STATE  CONSTITUENCY
# 0  Uttar Pradesh            80
# 1    Maharashtra            48
# 2    West Bengal            42
# 3          Bihar            40
# 4     Tamil Nadu            38

# %% [markdown]
# # Q2)which states has the least number of parlimentary constituencies

# %%
Num_const = data.groupby('STATE')['CONSTITUENCY'].nunique().sort_values(ascending=True).reset_index()
Num_const.head(5)
# Out:
#                        STATE  CONSTITUENCY
# 0  Andaman & Nicobar Islands             1
# 1                     Sikkim             1
# 2                 Puducherry             1
# 3                   Nagaland             1
# 4                    Mizoram             1

# %%
ax = px.bar(Num_cons,y='CONSTITUENCY',x='STATE',color = 'CONSTITUENCY', title='The Number of Constituencies from each State')
ax.show()

# %%
Num_cons
# Out:
#                         STATE  CONSTITUENCY
# 0               Uttar Pradesh            80
# 1                 Maharashtra            48
# 2                 West Bengal            42
# 3                       Bihar            40
# 4                  Tamil Nadu            38
# 5              Madhya Pradesh            29
# 6                   Karnataka            28
# 7                     Gujarat            26
# 8                   Rajasthan            25
# 9              Andhra Pradesh            25
# 10                     Odisha            21
# 11                     Kerala            20
# 12                  Telangana            17
# 13                      Assam            14
# 14                  Jharkhand            14
# 15                     Punjab            13
# 16               Chhattisgarh            11
# 17                    Haryana            10
# 18               NCT OF Delhi             7
# 19            Jammu & Kashmir             6
# ...

# %% [markdown]
# # Q3)Give some statics about Education level of candidates who contested in election

# %%
education = data['EDUCATION'].value_counts().reset_index()

# %%
education
# Out:
#                      index  EDUCATION
# 0                 Graduate        777
# 1             scholl level        588
# 2  Post Graduate/Doctorate        576
# 3               Illiterate         77

# %%
education.columns = ['EDUCATION','COUNT']
ax = px.bar(education,x = 'EDUCATION', y = 'COUNT',color = 'EDUCATION', title= 'Education Level of the Candidates')
ax.show()

# %% [markdown]
# # Q4)give winning candidates education level

# %%
winner = data[data['WINNER']==1]
educationlevel=winner['EDUCATION'].value_counts().reset_index()
educationlevel.columns=['EDUCATION','COUNT']
educationlevel
# Out:
#                  EDUCATION  COUNT
# 0                 Graduate    231
# 1  Post Graduate/Doctorate    158
# 2             scholl level    132
# 3               Illiterate     18

# %%
ax = px.bar(winner,x = 'EDUCATION',y = 'WINNER', title='Winning Candidates Educational Degree').update_xaxes(categoryorder = "total descending")
ax.show()

# %% [markdown]
# # q5)details of youngest cndidates who won election

# %%
young_winner = data[data['WINNER']==1]
young_winner = young_winner.sort_values('AGE')

# %%
young_winner.head(3)
# Out:
#      WINNER  CRIMINALCASES   AGE  ASSETS  LIABILITIES  GENERAL VOTES  \
# 121       1            0.0  26.0       0            0         557561
# 287       1            0.0  28.0       0            0         781920
# 215       1            0.0  28.0       0            0         736605
#
#      POSTAL VOTES  TOTAL VOTES  OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# 121       3718.25       562190                              38.733845
# 287        158.00       782078                              46.597833
# 215       2624.00       739229                              33.366404
#
#      OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS  \
# 121                                  52.139840       1451418.0
# 287                                  54.547002       1678357.0
# 215                                  62.137994       2215489.0
#
#               STATE     CONSTITUENCY               NAME  PARTY  \
# 121  Andhra Pradesh            ARUKU   GODDETI. MADHAVI  YSRCP
# ...

# %%
young_winner = young_winner.sort_values('AGE').head(10)
ax = px.bar(young_winner,x = 'NAME',y = 'AGE',color = 'AGE',hover_data = ['PARTY','STATE','CONSTITUENCY'], title='Youngest Winners')
ax.show()

# %% [markdown]
# # q6)winning candidates profile of oldest

# %%
old_winner = data[data['WINNER']==1]
old_winner = old_winner.sort_values('AGE',ascending = False).head(3)
old_winner
# Out:
#       WINNER  CRIMINALCASES   AGE  ASSETS  LIABILITIES  GENERAL VOTES  \
# 1647       1            0.0  86.0       0            0         657505
# 1788       1            1.0  83.0       0            0         106596
# 1231       1            0.0  80.0       0            0         726463
#
#       POSTAL VOTES  TOTAL VOTES  OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# 1647         501.0       658006                              35.980914
# 1788         154.0       106750                               8.245338
# 1231         365.0       726828                              43.994296
#
#       OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS  \
# 1647                                  55.584784       1828764.0
# 1788                                  57.127414       1294671.0
# 1231                                  51.841523       1652096.0
#
#                 STATE CONSTITUENCY                      NAME PARTY  \
# 1647    Uttar Pradesh      SAMBHAL  DR. SHAFIQUR REHMAN BARQ    SP
# ...

# %%
ax = px.bar(old_winner,x = 'NAME',y = 'AGE',color = 'AGE',hover_data = ['PARTY','STATE','CONSTITUENCY'], title = 'Oldest Winners and their Details:')
ax.show()

# %% [markdown]
# # q7)which party has the highst number of criminal cases among winning candidates

# %%
criminal_cases = data.groupby('PARTY')['CRIMINALCASES'].sum().reset_index().sort_values('CRIMINALCASES',ascending=False).head(5)
criminal_casescriminal_cases = data.groupby('PARTY')['CRIMINALCASES'].sum().reset_index().sort_values('CRIMINALCASES',ascending=False).head(5)
criminal_cases
# Out:
#      PARTY  CRIMINALCASES
# 26     BJP          319.5
# 46     INC          277.5
# 35     BSP           92.5
# 38  CPI(M)           88.0
# 47     IND           88.0

# %%
ax = px.bar(criminal_cases, x = 'PARTY',y = 'CRIMINALCASES',color = 'PARTY', title='Total Criminal Cases by respective parties')
ax.show()

# %% [markdown]
# # q8)highest number of female winner from whichstate

# %%
Female_winners = data[(data['WINNER']==1) & (data['GENDER']=='FEMALE')]
Female_winners.head(5)
# Out:
#     WINNER  CRIMINALCASES   AGE  ASSETS  LIABILITIES  GENERAL VOTES  \
# 27       1            2.5  32.0       0            0         532493
# 37       1            2.5  69.0       0            0         493204
# 47       1            0.0  46.0       0            0         482003
# 57       1            0.0  43.0       0            0         467598
# 59       1            1.0  33.0       0            0         507844
#
#     POSTAL VOTES  TOTAL VOTES  OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# 27       1322.00       533815                              42.139053
# 37       1250.00       494454                              28.811649
# 47       3718.25       485958                              33.294920
# 57        916.00       468514                              26.871808
# 59       3103.00       510947                              27.873521
#
#     OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS           STATE  \
# ...

# %%
ax = px.histogram(Female_winners, 'STATE', title = 'Female Winners from different States')
ax.show()

# %% [markdown]
# # q9) highest number of male winner from which state

# %%
male_winners = data[(data['WINNER']==1) & (data['GENDER']=='MALE')]
male_winners.head(5)
# Out:
#     WINNER  CRIMINALCASES   AGE  ASSETS  LIABILITIES  GENERAL VOTES  \
# 0        1            2.5  52.0       0            0         376892
# 3        1            2.5  58.0       0            0         644459
# 6        1            0.0  37.0       0            0         696961
# 9        1            0.0  58.0       0            0         745810
# 11       1            0.0  69.0       0            0         638241
#
#     POSTAL VOTES  TOTAL VOTES  OVER TOTAL ELECTORS \nIN CONSTITUENCY  \
# 0         482.00       377374                              25.330684
# 3        2416.00       646875                              33.383823
# 6        3718.25       704660                              37.856533
# 9        3718.25       749834                              41.384970
# 11       3381.00       641622                              39.044323
#
#     OVER TOTAL VOTES POLLED \nIN CONSTITUENCY  TOTAL ELECTORS          STATE  \
# ...

# %%
ax = px.histogram(male_winners, 'STATE', title='Male Winners from different States')
ax.show()

# %% [markdown]
# # q10)which are the top ten states with most votes

# %%
votes = data.groupby('STATE')['TOTAL VOTES'].sum().sort_values(ascending = False).reset_index()
votes.head(10)
# Out:
#             STATE  TOTAL VOTES
# 0   Uttar Pradesh     83732192
# 1     West Bengal     55414939
# 2     Maharashtra     52011437
# 3      Tamil Nadu     40629837
# 4           Bihar     38051064
# 5  Madhya Pradesh     35366613
# 6       Karnataka     33789397
# 7       Rajasthan     31481301
# 8  Andhra Pradesh     30544833
# 9         Gujarat     27823175

# %%
ax = px.bar(votes,x = 'STATE',y = 'TOTAL VOTES',color='STATE', title='Total Votes cast State Wise')
ax.show()

# %% [markdown]
# # Q11)which catagory of candidates won more seats

# %%
df = data[data['WINNER']==1]
category = df['CATEGORY'].value_counts().reset_index()
category.columns= ['CATEGORY','COUNT']
category
# Out:
#   CATEGORY  COUNT
# 0  GENERAL    399
# 1       SC     85
# 2       ST     55

# %%
ax = px.bar(category,x = 'CATEGORY', y = 'COUNT', color = 'CATEGORY', title='Winners from Various Categories')
ax.show()
